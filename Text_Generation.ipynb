# %%
import numpy
import sys
import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Using TensorFlow backend.

# %%
#load data
file = open("frankenstein-2.txt", encoding="utf8")

# %%
#tokenization and standardization
def tokenize_words(input):
    input = input.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(input)
    filtered = filter(lambda token: token not in stopwords.words('english'), tokens)
    return " ".join(filtered)
processed_inputs = tokenize_words(file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-fa82bad1a893> in <module>
#       6     filtered = filter(lambda token: token not in stopwords.words('english'), tokens)
#       7     return " ".join(filtered)
# ----> 8 processed_inputs = tokenize_words(file)
#
# <ipython-input-13-fa82bad1a893> in tokenize_words(input)
#       1 #tokenization and standardization
#       2 def tokenize_words(input):
# ----> 3     input = input.lower()
#       4     tokenizer = RegexpTokenizer(r'\w+')
#       5     tokens = tokenizer.tokenize(input)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'lower'

# %%
print(type(input))
# Out:
# <class 'method'>

# %%
def tokenize_words(input):
    # lowercase everything to standardize it
    input = input.lower()

    # instantiate the tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(input)

    # if the created token isn't in the stop words, make it part of "filtered"
    filtered = filter(lambda token: token not in stopwords.words('english'), tokens)
    return " ".join(filtered)

# %%
# preprocess the input data, make tokens
processed_inputs = tokenize_words(file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-693465b3d380> in <module>
#       1 # preprocess the input data, make tokens
# ----> 2 processed_inputs = tokenize_words(file)
#
# <ipython-input-17-2738528f8099> in tokenize_words(input)
#       1 def tokenize_words(input):
#       2     # lowercase everything to standardize it
# ----> 3     input = input.lower()
#       4
#       5     # instantiate the tokenizer
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'lower'

# %%
#characters to numbers
chars = sorted(list(set(processed_inputs)))
char_to_num = dict((c, i) for i, c in enumerate(chars))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-21bb08c9a033> in <module>
#       1 #characters to numbers
# ----> 2 chars = sorted(list(set(processed_inputs)))
#       3 char_to_num = dict((c, i) for i, c in enumerate(chars))
#
# NameError: name 'processed_inputs' is not defined
